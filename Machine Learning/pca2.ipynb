# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_wine

# %%
X = load_wine().data
y = load_wine().target

# %%
x_train,x_test,y_train,y_test = train_test_split(X, y, random_state=50, test_size=0.3)

# %%
pca = PCA(n_components=2)
pca.fit(x_train)
pca.transform(x_test)
# pca.explained_variance_
# Out:
# array([[-428.33568164,   13.93764124],
#        [-293.77654412,  -15.22912536],
#        [-495.66390959,   -6.95578266],
#        [   6.30781068,  -12.0580597 ],
#        [-223.6115866 ,   -5.33380492],
#        [ -78.58840274,   -5.6379827 ],
#        [-408.45679897,    7.61290338],
#        [-401.76262857,  -14.4519247 ],
#        [  71.4138418 ,   -6.17089758],
#        [ -88.68155432,  -11.41361488],
#        [  21.78933488,   15.6935711 ],
#        [  56.84528769,   22.06681219],
#        [-209.69669699,  -10.6262141 ],
#        [ 546.25338097,  -20.84514102],
#        [-353.66111425,   -8.22677524],
#        [-358.78714608,  -15.11653152],
#        [-388.72885411,  -10.69325587],
#        [-153.66165797,   -9.32586668],
#        [ -63.54234405,   -2.9708513 ],
#        [ 286.76235747,   12.37435008],
#        [ 241.38204797,   -9.92538623],
#        [-421.68167079,   -8.13148492],
#        [ 246.44065655,   -7.00409268],
#        [ -98.51050538,   -1.24227724],
#        [ 321.60878924,    3.77819042],
#        [   6.93813928,   24.92099632],
#        [-358.69049395,   -9.18585745],
#        [ 212.041737  ,   34.52349571],
#        [ -13.01546435,   27.24247831],
#        [-307.64203654,   -4.00652325],
#        [ 286.50867661,   -2.60723252],
#        [ 271.43604391,   -8.37927413],
#        [ -23.4413474 ,    4.48879948],
#        [ -48.62464721,   -7.10773647],
#        [ 376.33785718,  -16.07458152],
#        [-395.70413768,   -9.58116698],
#        [ -59.72419594,  -14.02075864],
#        [-253.6702114 ,   -8.77910114],
#        [ 506.74605587,   10.80388519],
#        [ 496.46923627,   -7.03044747],
#        [-393.69128572,   -8.61014909],
#        [-273.27471605,   15.43374209],
#        [-461.57122821,   -1.50184043],
#        [-303.68264762,   -9.92232778],
#        [-143.8740958 ,  -20.68448583],
#        [-345.68644914,  -10.38022723],
#        [-367.64483297,   -7.03192003],
#        [-381.66098608,   -8.76131252],
#        [-143.31337897,   13.43301246],
#        [-293.27045925,   15.92330217],
#        [ 773.45845994,  -11.50027246],
#        [-293.63530131,   -7.0980352 ],
#        [ -23.48727974,    1.46723958],
#        [-113.6774417 ,  -11.13140085]])
